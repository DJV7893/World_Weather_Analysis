# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 2 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | guajara-mirim
# City not found. Skipping...
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | carlsbad
# Processing Record 8 of Set 1 | lazaro cardenas
# Processing Record 9 of Set 1 | dingle
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | kodiak
# City not found. Skipping...
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | ashland
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | hay river
# Processing Record 16 of Set 1 | srednekolymsk
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | batsfjord
# Processing Record 19 of Set 1 | santa maria da vitoria
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | dongying
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | isangel
# Processing Record 24 of Set 1 | tocopilla
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | mercedes
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | samoded
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | alexandria
# Processing Record 31 of Set 1 | bowmore
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | kloulklubed
# Processing Record 34 of Set 1 | shibetsu
# Processing Record 35 of Set 1 | aksarka
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | teya
# Processing Record 39 of Set 1 | urucara
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | mildura
# Processing Record 43 of Set 1 | lowestoft
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | mackay
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | airai
# Processing Record 50 of Set 1 | hervey bay
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | rio gallegos
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | leningradskiy
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | tazovskiy
# Processing Record 10 of Set 2 | santa cruz del sur
# Processing Record 11 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 2 | belene
# Processing Record 13 of Set 2 | samandag
# Processing Record 14 of Set 2 | tilichiki
# Processing Record 15 of Set 2 | ancud
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | souillac
# Processing Record 19 of Set 2 | takhtamygda
# Processing Record 20 of Set 2 | pevek
# Processing Record 21 of Set 2 | lavrentiya
# Processing Record 22 of Set 2 | marawi
# Processing Record 23 of Set 2 | okha
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | jinka
# Processing Record 26 of Set 2 | dhidhdhoo
# Processing Record 27 of Set 2 | roebourne
# Processing Record 28 of Set 2 | nova olimpia
# Processing Record 29 of Set 2 | candawaga
# City not found. Skipping...
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | busselton
# Processing Record 32 of Set 2 | nouadhibou
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | winnemucca
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | cururupu
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | riohacha
# Processing Record 39 of Set 2 | yinchuan
# Processing Record 40 of Set 2 | pisco
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | mweka
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | juneau
# Processing Record 46 of Set 2 | ibia
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | malanje
# Processing Record 49 of Set 2 | hovd
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | san jeronimo
# Processing Record 3 of Set 3 | bo phloi
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | kentau
# Processing Record 10 of Set 3 | buraydah
# Processing Record 11 of Set 3 | rawson
# Processing Record 12 of Set 3 | smithers
# Processing Record 13 of Set 3 | eureka
# Processing Record 14 of Set 3 | nikolskoye
# Processing Record 15 of Set 3 | severo-kurilsk
# Processing Record 16 of Set 3 | zhezkazgan
# Processing Record 17 of Set 3 | lucapa
# Processing Record 18 of Set 3 | henties bay
# Processing Record 19 of Set 3 | biak
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | west bay
# Processing Record 22 of Set 3 | vila do maio
# Processing Record 23 of Set 3 | sinnamary
# Processing Record 24 of Set 3 | vao
# Processing Record 25 of Set 3 | coquimbo
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 3 | deputatskiy
# Processing Record 29 of Set 3 | vaitape
# Processing Record 30 of Set 3 | carbonia
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | honiara
# Processing Record 33 of Set 3 | komsomolskiy
# Processing Record 34 of Set 3 | kulob
# Processing Record 35 of Set 3 | upernavik
# Processing Record 36 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 3 | northam
# Processing Record 38 of Set 3 | nishihara
# Processing Record 39 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 40 of Set 3 | grand gaube
# Processing Record 41 of Set 3 | asau
# Processing Record 42 of Set 3 | thinadhoo
# Processing Record 43 of Set 3 | orange cove
# Processing Record 44 of Set 3 | lima
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | bandarbeyla
# Processing Record 48 of Set 3 | dzhebariki-khaya
# Processing Record 49 of Set 3 | miles city
# Processing Record 50 of Set 3 | huarmey
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | islamabad
# Processing Record 3 of Set 4 | cam ranh
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | atambua
# Processing Record 6 of Set 4 | khuzdar
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | esperance
# Processing Record 9 of Set 4 | camacha
# Processing Record 10 of Set 4 | kavaratti
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | paragominas
# Processing Record 13 of Set 4 | salta
# Processing Record 14 of Set 4 | puerto escondido
# Processing Record 15 of Set 4 | rockingham
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | ibaiti
# Processing Record 18 of Set 4 | ushtobe
# Processing Record 19 of Set 4 | san quintin
# Processing Record 20 of Set 4 | necochea
# Processing Record 21 of Set 4 | surok
# Processing Record 22 of Set 4 | bani
# Processing Record 23 of Set 4 | menongue
# Processing Record 24 of Set 4 | bjornevatn
# Processing Record 25 of Set 4 | kasongo-lunda
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | safford
# Processing Record 28 of Set 4 | grindavik
# Processing Record 29 of Set 4 | nome
# Processing Record 30 of Set 4 | nizhneangarsk
# Processing Record 31 of Set 4 | vila velha
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | avera
# Processing Record 34 of Set 4 | sanming
# Processing Record 35 of Set 4 | sheopur
# Processing Record 36 of Set 4 | los llanos de aridane
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | sorong
# Processing Record 39 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 4 | ilo
# Processing Record 41 of Set 4 | preobrazheniye
# Processing Record 42 of Set 4 | san marcos
# Processing Record 43 of Set 4 | acapulco
# Processing Record 44 of Set 4 | saint-joseph
# Processing Record 45 of Set 4 | acarau
# Processing Record 46 of Set 4 | vilya
# Processing Record 47 of Set 4 | namatanai
# Processing Record 48 of Set 4 | rocha
# Processing Record 49 of Set 4 | flin flon
# Processing Record 50 of Set 4 | yeppoon
# Processing Record 1 of Set 5 | amapa
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | tongliao
# Processing Record 4 of Set 5 | beloha
# Processing Record 5 of Set 5 | baruun-urt
# Processing Record 6 of Set 5 | saint-philippe
# Processing Record 7 of Set 5 | sturgeon bay
# Processing Record 8 of Set 5 | kadhan
# Processing Record 9 of Set 5 | tashtyp
# Processing Record 10 of Set 5 | vila franca do campo
# Processing Record 11 of Set 5 | adrar
# Processing Record 12 of Set 5 | olafsvik
# Processing Record 13 of Set 5 | port hedland
# Processing Record 14 of Set 5 | iqaluit
# Processing Record 15 of Set 5 | klaksvik
# Processing Record 16 of Set 5 | laguna
# Processing Record 17 of Set 5 | chapais
# Processing Record 18 of Set 5 | paamiut
# Processing Record 19 of Set 5 | mareeba
# Processing Record 20 of Set 5 | chuy
# Processing Record 21 of Set 5 | waingapu
# Processing Record 22 of Set 5 | nowogard
# Processing Record 23 of Set 5 | lagoa
# Processing Record 24 of Set 5 | nichinan
# Processing Record 25 of Set 5 | kenora
# Processing Record 26 of Set 5 | waslala
# Processing Record 27 of Set 5 | kalemie
# Processing Record 28 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | tiznit
# Processing Record 31 of Set 5 | wamba
# Processing Record 32 of Set 5 | kresttsy
# Processing Record 33 of Set 5 | wanning
# Processing Record 34 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 5 | thunder bay
# Processing Record 36 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 5 | abu samrah
# Processing Record 38 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 5 | zhaotong
# Processing Record 40 of Set 5 | lagoa formosa
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | puntarenas
# Processing Record 43 of Set 5 | monrovia
# Processing Record 44 of Set 5 | nouakchott
# Processing Record 45 of Set 5 | hohhot
# Processing Record 46 of Set 5 | jomalig
# City not found. Skipping...
# Processing Record 47 of Set 5 | skjervoy
# Processing Record 48 of Set 5 | manaus
# Processing Record 49 of Set 5 | tsiroanomandidy
# Processing Record 50 of Set 5 | lata
# Processing Record 1 of Set 6 | russell
# Processing Record 2 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 6 | guerrero negro
# Processing Record 4 of Set 6 | butaritari
# Processing Record 5 of Set 6 | luderitz
# Processing Record 6 of Set 6 | pahrump
# Processing Record 7 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 6 | pachuquilla
# Processing Record 9 of Set 6 | waipawa
# Processing Record 10 of Set 6 | rajkot
# Processing Record 11 of Set 6 | ndele
# Processing Record 12 of Set 6 | kununurra
# Processing Record 13 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 6 | ust-maya
# Processing Record 15 of Set 6 | lemesos
# City not found. Skipping...
# Processing Record 16 of Set 6 | bandipur
# Processing Record 17 of Set 6 | port lincoln
# Processing Record 18 of Set 6 | tasiilaq
# Processing Record 19 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 6 | port macquarie
# Processing Record 21 of Set 6 | ballina
# Processing Record 22 of Set 6 | hobyo
# Processing Record 23 of Set 6 | fort-shevchenko
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | onega
# Processing Record 26 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 6 | acari
# Processing Record 28 of Set 6 | namibe
# Processing Record 29 of Set 6 | mahebourg
# Processing Record 30 of Set 6 | panarukan
# Processing Record 31 of Set 6 | monte patria
# Processing Record 32 of Set 6 | mogadishu
# Processing Record 33 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 6 | port keats
# Processing Record 35 of Set 6 | karatsu
# Processing Record 36 of Set 6 | tashtagol
# Processing Record 37 of Set 6 | kirakira
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | nyuksenitsa
# Processing Record 40 of Set 6 | banda aceh
# Processing Record 41 of Set 6 | cayenne
# Processing Record 42 of Set 6 | mirnyy
# Processing Record 43 of Set 6 | zhangye
# Processing Record 44 of Set 6 | fatehabad
# Processing Record 45 of Set 6 | merauke
# Processing Record 46 of Set 6 | anqing
# Processing Record 47 of Set 6 | adeje
# Processing Record 48 of Set 6 | pangnirtung
# Processing Record 49 of Set 6 | bethel
# Processing Record 50 of Set 6 | resistencia
# Processing Record 1 of Set 7 | liwale
# Processing Record 2 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 7 | sembakung
# Processing Record 4 of Set 7 | hanstholm
# Processing Record 5 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 7 | coahuayana
# Processing Record 7 of Set 7 | misratah
# Processing Record 8 of Set 7 | abhaynagar
# Processing Record 9 of Set 7 | amudat
# Processing Record 10 of Set 7 | ipixuna
# Processing Record 11 of Set 7 | peleduy
# Processing Record 12 of Set 7 | micheweni
# Processing Record 13 of Set 7 | krasnoarmeysk
# Processing Record 14 of Set 7 | moose factory
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | havre-saint-pierre
# Processing Record 17 of Set 7 | touros
# Processing Record 18 of Set 7 | makakilo city
# Processing Record 19 of Set 7 | virginia beach
# Processing Record 20 of Set 7 | kokologo
# Processing Record 21 of Set 7 | barsovo
# Processing Record 22 of Set 7 | homer
# Processing Record 23 of Set 7 | erzin
# Processing Record 24 of Set 7 | harper
# Processing Record 25 of Set 7 | tuatapere
# Processing Record 26 of Set 7 | statesville
# Processing Record 27 of Set 7 | novopokrovka
# Processing Record 28 of Set 7 | okhotsk
# Processing Record 29 of Set 7 | maumere
# Processing Record 30 of Set 7 | manokwari
# Processing Record 31 of Set 7 | cabo san lucas
# Processing Record 32 of Set 7 | pontes e lacerda
# Processing Record 33 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 7 | mananara
# Processing Record 35 of Set 7 | yangambi
# Processing Record 36 of Set 7 | praya
# Processing Record 37 of Set 7 | narsaq
# Processing Record 38 of Set 7 | baneh
# Processing Record 39 of Set 7 | jalu
# Processing Record 40 of Set 7 | mapiripan
# Processing Record 41 of Set 7 | catia la mar
# Processing Record 42 of Set 7 | tazmalt
# Processing Record 43 of Set 7 | challans
# Processing Record 44 of Set 7 | qabis
# City not found. Skipping...
# Processing Record 45 of Set 7 | santa cruz
# Processing Record 46 of Set 7 | villa guerrero
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | dunedin
# Processing Record 49 of Set 7 | brae
# Processing Record 50 of Set 7 | porosozero
# Processing Record 1 of Set 8 | hokitika
# Processing Record 2 of Set 8 | sydney
# Processing Record 3 of Set 8 | ostrovnoy
# Processing Record 4 of Set 8 | batticaloa
# Processing Record 5 of Set 8 | oktyabrskiy
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | husavik
# Processing Record 8 of Set 8 | mahibadhoo
# Processing Record 9 of Set 8 | broome
# Processing Record 10 of Set 8 | sao gabriel da cachoeira
# Processing Record 11 of Set 8 | nuuk
# Processing Record 12 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 8 | paka
# Processing Record 14 of Set 8 | narwar
# Processing Record 15 of Set 8 | seydi
# Processing Record 16 of Set 8 | kruisfontein
# Processing Record 17 of Set 8 | ambam
# Processing Record 18 of Set 8 | sao filipe
# Processing Record 19 of Set 8 | port augusta
# Processing Record 20 of Set 8 | dhemaji
# Processing Record 21 of Set 8 | te anau
# Processing Record 22 of Set 8 | flinders
# Processing Record 23 of Set 8 | bilibino
# Processing Record 24 of Set 8 | copiapo
# Processing Record 25 of Set 8 | aklavik
# Processing Record 26 of Set 8 | puerto narino
# Processing Record 27 of Set 8 | comodoro rivadavia
# Processing Record 28 of Set 8 | el balyana
# City not found. Skipping...
# Processing Record 29 of Set 8 | beavercreek
# Processing Record 30 of Set 8 | teguldet
# Processing Record 31 of Set 8 | kabompo
# Processing Record 32 of Set 8 | healdsburg
# Processing Record 33 of Set 8 | zeya
# Processing Record 34 of Set 8 | alugan
# Processing Record 35 of Set 8 | escarcega
# Processing Record 36 of Set 8 | palu
# Processing Record 37 of Set 8 | bowen
# Processing Record 38 of Set 8 | riberalta
# Processing Record 39 of Set 8 | samana
# Processing Record 40 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 41 of Set 8 | port hawkesbury
# Processing Record 42 of Set 8 | arman
# Processing Record 43 of Set 8 | kingsville
# Processing Record 44 of Set 8 | azuaga
# Processing Record 45 of Set 8 | praia
# Processing Record 46 of Set 8 | bengkulu
# Processing Record 47 of Set 8 | tautira
# Processing Record 48 of Set 8 | maniitsoq
# Processing Record 49 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 8 | cabra
# Processing Record 1 of Set 9 | san lorenzo
# Processing Record 2 of Set 9 | keningau
# Processing Record 3 of Set 9 | taoudenni
# Processing Record 4 of Set 9 | zavetnoye
# Processing Record 5 of Set 9 | paita
# Processing Record 6 of Set 9 | port-gentil
# Processing Record 7 of Set 9 | port blair
# Processing Record 8 of Set 9 | maner
# Processing Record 9 of Set 9 | geraldton
# Processing Record 10 of Set 9 | baiyin
# Processing Record 11 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 9 | murgab
# Processing Record 13 of Set 9 | fort nelson
# Processing Record 14 of Set 9 | oyek
# Processing Record 15 of Set 9 | solnechnyy
# Processing Record 16 of Set 9 | mehriz
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | sartell
# Processing Record 19 of Set 9 | mago
# Processing Record 20 of Set 9 | litokhoron
# City not found. Skipping...
# Processing Record 21 of Set 9 | yuancheng
# Processing Record 22 of Set 9 | lagos
# Processing Record 23 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 9 | bonavista
# Processing Record 25 of Set 9 | omsukchan
# Processing Record 26 of Set 9 | naze
# Processing Record 27 of Set 9 | quelimane
# Processing Record 28 of Set 9 | moundou
# Processing Record 29 of Set 9 | kirkwall
# Processing Record 30 of Set 9 | lorengau
# Processing Record 31 of Set 9 | boyuibe
# Processing Record 32 of Set 9 | hirara
# Processing Record 33 of Set 9 | honningsvag
# Processing Record 34 of Set 9 | dudinka
# Processing Record 35 of Set 9 | santomera
# Processing Record 36 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 9 | cavalcante
# Processing Record 38 of Set 9 | mehamn
# Processing Record 39 of Set 9 | kaa-khem
# Processing Record 40 of Set 9 | refojos de basto
# Processing Record 41 of Set 9 | fort smith
# Processing Record 42 of Set 9 | hukuntsi
# Processing Record 43 of Set 9 | havoysund
# Processing Record 44 of Set 9 | palatka
# Processing Record 45 of Set 9 | liverpool
# Processing Record 46 of Set 9 | nemuro
# Processing Record 47 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 9 | mabaruma
# Processing Record 49 of Set 9 | barabinsk
# Processing Record 50 of Set 9 | gizo
# Processing Record 1 of Set 10 | andros town
# Processing Record 2 of Set 10 | malaya purga
# Processing Record 3 of Set 10 | zyryanka
# Processing Record 4 of Set 10 | urumqi
# Processing Record 5 of Set 10 | salalah
# Processing Record 6 of Set 10 | morro bay
# Processing Record 7 of Set 10 | norman wells
# Processing Record 8 of Set 10 | vilhena
# Processing Record 9 of Set 10 | durban
# Processing Record 10 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 10 | lac du bonnet
# Processing Record 12 of Set 10 | kalmunai
# Processing Record 13 of Set 10 | zadar
# Processing Record 14 of Set 10 | linguere
# Processing Record 15 of Set 10 | seoul
# Processing Record 16 of Set 10 | aksum
# Processing Record 17 of Set 10 | kribi
# Processing Record 18 of Set 10 | college
# Processing Record 19 of Set 10 | yumen
# Processing Record 20 of Set 10 | shemysheyka
# Processing Record 21 of Set 10 | vereshchagino
# Processing Record 22 of Set 10 | canico
# Processing Record 23 of Set 10 | kranuan
# Processing Record 24 of Set 10 | san andres
# Processing Record 25 of Set 10 | santa maria
# Processing Record 26 of Set 10 | talcahuano
# Processing Record 27 of Set 10 | pechenga
# Processing Record 28 of Set 10 | elko
# Processing Record 29 of Set 10 | morant bay
# Processing Record 30 of Set 10 | fereydun kenar
# Processing Record 31 of Set 10 | launceston
# Processing Record 32 of Set 10 | anadyr
# Processing Record 33 of Set 10 | birao
# Processing Record 34 of Set 10 | haines junction
# Processing Record 35 of Set 10 | beisfjord
# Processing Record 36 of Set 10 | saint-louis
# Processing Record 37 of Set 10 | noumea
# Processing Record 38 of Set 10 | emerald
# Processing Record 39 of Set 10 | muskegon
# Processing Record 40 of Set 10 | colares
# Processing Record 41 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 42 of Set 10 | poum
# Processing Record 43 of Set 10 | guaranda
# Processing Record 44 of Set 10 | hofn
# Processing Record 45 of Set 10 | antibes
# Processing Record 46 of Set 10 | salina
# Processing Record 47 of Set 10 | pizarro
# Processing Record 48 of Set 10 | campbellton
# Processing Record 49 of Set 10 | zhaoyang
# Processing Record 50 of Set 10 | kurilsk
# Processing Record 1 of Set 11 | kyaikto
# Processing Record 2 of Set 11 | novikovo
# Processing Record 3 of Set 11 | bambanglipuro
# Processing Record 4 of Set 11 | dinar
# Processing Record 5 of Set 11 | keetmanshoop
# Processing Record 6 of Set 11 | filingue
# Processing Record 7 of Set 11 | kulhudhuffushi
# Processing Record 8 of Set 11 | la union
# Processing Record 9 of Set 11 | nanortalik
# Processing Record 10 of Set 11 | alice springs
# Processing Record 11 of Set 11 | lensk
# Processing Record 12 of Set 11 | mananjary
# Processing Record 13 of Set 11 | miahuatlan
# Processing Record 14 of Set 11 | beringovskiy
# Processing Record 15 of Set 11 | arona
# Processing Record 16 of Set 11 | dergachi
# Processing Record 17 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 11 | rafaela
# Processing Record 19 of Set 11 | petropavl
# Processing Record 20 of Set 11 | manggar
# Processing Record 21 of Set 11 | nur
# Processing Record 22 of Set 11 | acucena
# Processing Record 23 of Set 11 | shihezi
# Processing Record 24 of Set 11 | miramar
# Processing Record 25 of Set 11 | broken hill
# Processing Record 26 of Set 11 | wakkanai
# Processing Record 27 of Set 11 | bata
# Processing Record 28 of Set 11 | bismarck
# Processing Record 29 of Set 11 | san policarpo
# Processing Record 30 of Set 11 | kempele
# Processing Record 31 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 11 | skopelos
# Processing Record 34 of Set 11 | makat
# Processing Record 35 of Set 11 | marsaxlokk
# Processing Record 36 of Set 11 | omboue
# Processing Record 37 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 38 of Set 11 | tatvan
# Processing Record 39 of Set 11 | christchurch
# Processing Record 40 of Set 11 | brunswick
# Processing Record 41 of Set 11 | nelson bay
# Processing Record 42 of Set 11 | nouna
# Processing Record 43 of Set 11 | assiniboia
# Processing Record 44 of Set 11 | powell
# Processing Record 45 of Set 11 | aguilas
# Processing Record 46 of Set 11 | rajpura
# Processing Record 47 of Set 11 | bikaner
# Processing Record 48 of Set 11 | komyshuvakha
# Processing Record 49 of Set 11 | boyabat
# Processing Record 50 of Set 11 | coihaique
# Processing Record 1 of Set 12 | santa isabel
# Processing Record 2 of Set 12 | itaituba
# Processing Record 3 of Set 12 | goundam
# Processing Record 4 of Set 12 | saldanha
# Processing Record 5 of Set 12 | katha
# City not found. Skipping...
# Processing Record 6 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 12 | mangrol
# Processing Record 8 of Set 12 | nakamura
# Processing Record 9 of Set 12 | sosnovo-ozerskoye
# Processing Record 10 of Set 12 | urengoy
# Processing Record 11 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 12 | inhambane
# Processing Record 13 of Set 12 | cooma
# Processing Record 14 of Set 12 | sindor
# Processing Record 15 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 12 | blagoveshchenka
# Processing Record 17 of Set 12 | hasaki
# Processing Record 18 of Set 12 | dwarka
# Processing Record 19 of Set 12 | mirai
# Processing Record 20 of Set 12 | cravo norte
# Processing Record 21 of Set 12 | bojnurd
# Processing Record 22 of Set 12 | penza
# Processing Record 23 of Set 12 | champerico
# Processing Record 24 of Set 12 | lhokseumawe
# Processing Record 25 of Set 12 | zempoala
# Processing Record 26 of Set 12 | uren
# Processing Record 27 of Set 12 | phan thiet
# Processing Record 28 of Set 12 | khash
# Processing Record 29 of Set 12 | tarpon springs
# Processing Record 30 of Set 12 | koutsouras
# Processing Record 31 of Set 12 | volary
# Processing Record 32 of Set 12 | iberia
# Processing Record 33 of Set 12 | tura
# Processing Record 34 of Set 12 | wajima
# Processing Record 35 of Set 12 | chara
# Processing Record 36 of Set 12 | uglovskoye
# Processing Record 37 of Set 12 | porciuncula
# Processing Record 38 of Set 12 | the valley
# Processing Record 39 of Set 12 | quatre cocos
# Processing Record 40 of Set 12 | tigil
# Processing Record 41 of Set 12 | lakes entrance
# Processing Record 42 of Set 12 | taltal
# Processing Record 43 of Set 12 | maracaibo
# Processing Record 44 of Set 12 | hambantota
# Processing Record 45 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | dandong
# Processing Record 47 of Set 12 | yantal
# Processing Record 48 of Set 12 | nyrob
# Processing Record 49 of Set 12 | am timan
# Processing Record 50 of Set 12 | sept-iles
# Processing Record 1 of Set 13 | mongomo
# Processing Record 2 of Set 13 | sapa
# Processing Record 3 of Set 13 | elliot
# Processing Record 4 of Set 13 | portgordon
# Processing Record 5 of Set 13 | thermon
# City not found. Skipping...
# Processing Record 6 of Set 13 | saint-augustin
# Processing Record 7 of Set 13 | san isidro
# Processing Record 8 of Set 13 | mattru
# Processing Record 9 of Set 13 | tokzar
# City not found. Skipping...
# Processing Record 10 of Set 13 | kimbe
# Processing Record 11 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 12 of Set 13 | berdigestyakh
# Processing Record 13 of Set 13 | codrington
# Processing Record 14 of Set 13 | lethem
# Processing Record 15 of Set 13 | port hardy
# Processing Record 16 of Set 13 | visby
# Processing Record 17 of Set 13 | leh
# Processing Record 18 of Set 13 | nezhinka
# Processing Record 19 of Set 13 | medina del campo
# Processing Record 20 of Set 13 | mahuva
# Processing Record 21 of Set 13 | pangody
# Processing Record 22 of Set 13 | channagiri
# Processing Record 23 of Set 13 | ulaangom
# Processing Record 24 of Set 13 | borba
# Processing Record 25 of Set 13 | quang ngai
# Processing Record 26 of Set 13 | maarianhamina
# Processing Record 27 of Set 13 | ciudad bolivar
# Processing Record 28 of Set 13 | longyearbyen
# Processing Record 29 of Set 13 | huilong
# Processing Record 30 of Set 13 | montepuez
# Processing Record 31 of Set 13 | great bend
# Processing Record 32 of Set 13 | wahiawa
# Processing Record 33 of Set 13 | arroyo
# Processing Record 34 of Set 13 | maputo
# Processing Record 35 of Set 13 | skelleftea
# Processing Record 36 of Set 13 | sisimiut
# Processing Record 37 of Set 13 | fonte boa
# Processing Record 38 of Set 13 | padang
# Processing Record 39 of Set 13 | kuopio
# Processing Record 40 of Set 13 | cap malheureux
# Processing Record 41 of Set 13 | esmeraldas
# Processing Record 42 of Set 13 | la romana
# Processing Record 43 of Set 13 | minot
# Processing Record 44 of Set 13 | kambove
# Processing Record 45 of Set 13 | ardmore
# Processing Record 46 of Set 13 | baudh
# Processing Record 47 of Set 13 | pomabamba
# Processing Record 48 of Set 13 | mnogovershinnyy
# Processing Record 49 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 13 | junagarh
# Processing Record 1 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 2 of Set 14 | dombarovskiy
# Processing Record 3 of Set 14 | nhulunbuy
# Processing Record 4 of Set 14 | goderich
# Processing Record 5 of Set 14 | mlonggo
# Processing Record 6 of Set 14 | samarai
# Processing Record 7 of Set 14 | sol-iletsk
# Processing Record 8 of Set 14 | ayagoz
# Processing Record 9 of Set 14 | tecolutla
# Processing Record 10 of Set 14 | portland
# Processing Record 11 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 14 | karak
# Processing Record 13 of Set 14 | vredendal
# Processing Record 14 of Set 14 | dzilam gonzalez
# Processing Record 15 of Set 14 | esso
# Processing Record 16 of Set 14 | matara
# Processing Record 17 of Set 14 | shingu
# Processing Record 18 of Set 14 | golynki
# Processing Record 19 of Set 14 | cockburn town
# Processing Record 20 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 14 | oranjemund
# Processing Record 22 of Set 14 | oran
# Processing Record 23 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 14 | bataipora
# Processing Record 25 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 14 | kondinskoye
# Processing Record 27 of Set 14 | metaxades
# Processing Record 28 of Set 14 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 29 of Set 14 | buta
# Processing Record 30 of Set 14 | winsum
# Processing Record 31 of Set 14 | jumla
# Processing Record 32 of Set 14 | aykhal
# Processing Record 33 of Set 14 | astaneh-ye ashrafiyeh
# Processing Record 34 of Set 14 | savannah bight
# Processing Record 35 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 14 | wonthaggi
# Processing Record 37 of Set 14 | gornoye loo
# Processing Record 38 of Set 14 | lahan
# Processing Record 39 of Set 14 | uyuni
# Processing Record 40 of Set 14 | banjar
# Processing Record 41 of Set 14 | bayevo
# Processing Record 42 of Set 14 | jiuquan
# Processing Record 43 of Set 14 | gejiu
# Processing Record 44 of Set 14 | bubaque
# Processing Record 45 of Set 14 | muros
# Processing Record 46 of Set 14 | roma
# Processing Record 47 of Set 14 | panzhihua
# Processing Record 48 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 14 | ndouci
# City not found. Skipping...
# Processing Record 50 of Set 14 | rochegda
# Processing Record 1 of Set 15 | prainha
# Processing Record 2 of Set 15 | beyneu
# Processing Record 3 of Set 15 | khowst
# Processing Record 4 of Set 15 | khorinsk
# Processing Record 5 of Set 15 | anjar
# Processing Record 6 of Set 15 | burla
# Processing Record 7 of Set 15 | mut
# Processing Record 8 of Set 15 | labuan
# Processing Record 9 of Set 15 | ercis
# Processing Record 10 of Set 15 | severiano melo
# Processing Record 11 of Set 15 | sogdiondon
# City not found. Skipping...
# Processing Record 12 of Set 15 | mayo
# Processing Record 13 of Set 15 | octeville
# Processing Record 14 of Set 15 | terre haute
# Processing Record 15 of Set 15 | aracaju
# Processing Record 16 of Set 15 | bobcaygeon
# Processing Record 17 of Set 15 | mahmudabad
# Processing Record 18 of Set 15 | lerwick
# Processing Record 19 of Set 15 | kurtamysh
# Processing Record 20 of Set 15 | hereford
# Processing Record 21 of Set 15 | xai-xai
# Processing Record 22 of Set 15 | vaxjo
# Processing Record 23 of Set 15 | yuxia
# Processing Record 24 of Set 15 | grand forks
# Processing Record 25 of Set 15 | tagab
# Processing Record 26 of Set 15 | wasilla
# Processing Record 27 of Set 15 | shelburne
# Processing Record 28 of Set 15 | seddon
# Processing Record 29 of Set 15 | altay
# Processing Record 30 of Set 15 | mahon
# Processing Record 31 of Set 15 | kjollefjord
# Processing Record 32 of Set 15 | abnub
# Processing Record 33 of Set 15 | iquitos
# Processing Record 34 of Set 15 | noyabrsk
# Processing Record 35 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 36 of Set 15 | manta
# Processing Record 37 of Set 15 | malakal
# Processing Record 38 of Set 15 | choucheng
# City not found. Skipping...
# Processing Record 39 of Set 15 | auki
# Processing Record 40 of Set 15 | kazlu ruda
# Processing Record 41 of Set 15 | kenai
# Processing Record 42 of Set 15 | novo aripuana
# Processing Record 43 of Set 15 | liseleje
# Processing Record 44 of Set 15 | denpasar
# Processing Record 45 of Set 15 | zelenoborskiy
# Processing Record 46 of Set 15 | laval
# Processing Record 47 of Set 15 | macas
# Processing Record 48 of Set 15 | puga
# Processing Record 49 of Set 15 | agadez
# Processing Record 50 of Set 15 | kieta
# Processing Record 1 of Set 16 | artigas
# Processing Record 2 of Set 16 | barahona
# Processing Record 3 of Set 16 | kichera
# Processing Record 4 of Set 16 | luena
# Processing Record 5 of Set 16 | kupang
# Processing Record 6 of Set 16 | kot radha kishan
# Processing Record 7 of Set 16 | nizhniy kuranakh
# Processing Record 8 of Set 16 | elblag
# Processing Record 9 of Set 16 | albesti
# Processing Record 10 of Set 16 | waitati
# Processing Record 11 of Set 16 | sao joao da barra
# Processing Record 12 of Set 16 | boyolangu
# Processing Record 13 of Set 16 | koster
# Processing Record 14 of Set 16 | palmas de monte alto
# Processing Record 15 of Set 16 | luorong
# Processing Record 16 of Set 16 | aden
# Processing Record 17 of Set 16 | svetlyy
# Processing Record 18 of Set 16 | manavalakurichi
# Processing Record 19 of Set 16 | richards bay
# Processing Record 20 of Set 16 | athens
# Processing Record 21 of Set 16 | sechura
# Processing Record 22 of Set 16 | lisakovsk
# Processing Record 23 of Set 16 | yakima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini      TO -21.2000 -175.2000     79.38        83         100
# 1           Faanui      PF -16.4833 -151.7500     81.57        70          11
# 2         Carlsbad      US  33.1581 -117.3506     58.95        89         100
# 3  Lazaro Cardenas      MX  17.9583 -102.2000     71.15        72           5
# 4           Dingle      PH  10.9995  122.6711     78.28        83          63
# 5     Puerto Ayora      EC  -0.7393  -90.3518     76.55       100         100
# 6         Hermanus      ZA -34.4187   19.2345     71.80        62          38
# 7          Ashland      US  40.8167  -82.2665     61.34        73          67
# 8          Ushuaia      AR -54.8000  -68.3000     47.82        66          20
# 9        Hay River      CA  60.8156 -115.7999     13.98        85         100
#
#    Wind Speed Current Description
# 0       11.97       moderate rain
# 1       15.01          light rain
# 2        5.75                mist
# 3        4.16           clear sky
# 4        6.60       broken clouds
# 5        7.58          light rain
# 6       11.05    scattered clouds
# 7       19.73       broken clouds
# 8       26.46          few clouds
# 9       10.36          light snow

# %%
# Format the Lat and Lng columns
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df.head(10)
# Out:
#               City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini      TO  -21.20  -175.20     79.38        83         100
# 1           Faanui      PF  -16.48  -151.75     81.57        70          11
# 2         Carlsbad      US   33.16  -117.35     58.95        89         100
# 3  Lazaro Cardenas      MX   17.96  -102.20     71.15        72           5
# 4           Dingle      PH   11.00   122.67     78.28        83          63
# 5     Puerto Ayora      EC   -0.74   -90.35     76.55       100         100
# 6         Hermanus      ZA  -34.42    19.23     71.80        62          38
# 7          Ashland      US   40.82   -82.27     61.34        73          67
# 8          Ushuaia      AR  -54.80   -68.30     47.82        66          20
# 9        Hay River      CA   60.82  -115.80     13.98        85         100
#
#    Wind Speed Current Description
# 0       11.97       moderate rain
# 1       15.01          light rain
# 2        5.75                mist
# 3        4.16           clear sky
# 4        6.60       broken clouds
# 5        7.58          light rain
# 6       11.05    scattered clouds
# 7       19.73       broken clouds
# 8       26.46          few clouds
# 9       10.36          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
